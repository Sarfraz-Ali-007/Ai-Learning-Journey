# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (1.2.16)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.7.7)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.5.0)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.37.1 langchain-groq-1.1.2

# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
class BlogState(TypedDict):
  title: str
  outline: str
  content: str

# %%
def create_outline(state: BlogState) -> BlogState:

  #fetch title
  title = state['title']

  #call llm generate outline
  prompt = f'Generate a detailed outline for a blog on the topic - {title}'
  outline = llm.invoke(prompt).content

  #update state
  state['outline'] = outline

  return state

# %%
def create_blog(state: BlogState) -> BlogState:

  title = state['title']
  outline = state['outline']

  prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

  content = llm.invoke(prompt).content

  state['content'] = content

  return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance\n* Thesis statement: The rise of AI is transforming the world, and its impact will be felt across various industries and aspects of our lives.\n\n**II. History of AI**\n\n* Early beginnings: The Dartmouth Summer Research Project on Artificial Intelligence (1956)\n* Key milestones:\n\t+ Development of the first AI program, Logical Theorist (1956)\n\t+ Creation of the first AI laboratory (1960s)\n\t+ Introduction of expert systems (1970s)\n\t+ Rise of machine learning (1980s)\n* Current state: AI\'s increasing presence in our daily lives\n\n**III. Types of AI**\n\n* **Narrow or Weak AI**: Designed to perform a specific task, e.g., image recognition, language translation\n* **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task\n* **Superintelligence**: An AI system that significantly surpasses human intelligence\n* Examples of AI applications: virtual assistants, self-driving cars, chatbots\n\n**IV. AI Technologies**\n\n* **Machine Learning (ML)**: A subset of AI that enables systems to learn from data\n* **Deep Learning (DL)**: A type of ML that uses neural networks to analyze data\n* **Natural Language Processing (NLP)**: A field of AI that deals with human-computer interaction\n* **Computer Vision**: A field of AI that enables computers to interpret and understand visual data\n\n**V. Impact of AI on Industries**\n\n* **Healthcare**: AI-assisted diagnosis, personalized medicine, and patient care\n* **Finance**: AI-powered trading, risk management, and customer service\n* **Transportation**: Self-driving cars, route optimization, and logistics management\n* **Education**: AI-based learning platforms, adaptive learning, and student assessment\n* **Customer Service**: Chatbots, virtual assistants, and sentiment analysis\n\n**VI. Benefits of AI**\n\n* **Increased Efficiency**: Automation of repetitive tasks and processes\n* **Improved Accuracy**: Reduced errors and enhanced decision-making\n* **Enhanced Customer Experience**: Personalized services and support\n* **New Business Opportunities**: Creation of new industries and job roles\n\n**VII. Challenges and Concerns**\n\n* **Job Displacement**: The potential for AI to replace human workers\n* **Bias and Discrimination**: The risk of AI systems perpetuating existing biases\n* **Security and Privacy**: The vulnerability of AI systems to cyber attacks and data breaches\n* **Ethics and Accountability**: The need for responsible AI development and deployment\n\n**VIII. Future of AI**\n\n* **Trends and Predictions**: The growth of AI adoption, advancements in AI technologies, and emerging applications\n* **Potential Breakthroughs**: The development of more sophisticated AI systems, such as general or strong AI\n* **Call to Action**: The need for individuals, organizations, and governments to work together to ensure the responsible development and deployment of AI\n\n**IX. Conclusion**\n\n* Recap of the rise of AI and its impact on various industries and aspects of our lives\n* Final thoughts: The future of AI holds tremendous promise, but it also requires careful consideration and responsible development to ensure that its benefits are realized and its risks are mitigated.\n\nThis outline provides a comprehensive framework for exploring the topic of the rise of AI, covering its history, types, technologies, impact on industries, benefits, challenges, and future prospects.', 'content': '**The Rise of AI: Transforming the World and Our Lives**\n\nArtificial Intelligence (AI) has become an integral part of our daily lives, and its growing importance cannot be overstated. From virtual assistants to self-driving cars, AI is revolutionizing the way we live, work, and interact with each other. The rise of AI is transformi ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance
# * Thesis statement: The rise of AI is transforming the world, and its impact will be felt across various industries and aspects of our lives.
#
# **II. History of AI**
#
# * Early beginnings: The Dartmouth Summer Research Project on Artificial Intelligence (1956)
# * Key milestones:
# 	+ Development of the first AI program, Logical Theorist (1956)
# 	+ Creation of the first AI laboratory (1960s)
# 	+ Introduction of expert systems (1970s)
# 	+ Rise of machine learning (1980s)
# * Current state: AI's increasing presence in our daily lives
#
# **III. Types of AI**
#
# * **Narrow or Weak AI**: Designed to perform a specific task, e.g., image recognition, language translation
# * **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task
# * **Superintelligence**: An AI system that significantly surpasses human intelligence
# * Examples of AI applications: virtual assistants, self-driving cars, chatbots
#
# **IV. AI Technologies**
#
# * **Machine Learning (ML)**: A subset of AI that enables systems to learn from data
# * **Deep Learning (DL)**: A type of ML that uses neural networks to analyze data
# * **Natural Language Processing (NLP)**: A field of AI that deals with human-computer interaction
# * **Computer Vision**: A field of AI that enables computers to interpret and understand visual data
#
# **V. Impact of AI on Industries**
#
# * **Healthcare**: AI-assisted diagnosis, personalized medicine, and patient care
# * **Finance**: AI-powered trading, risk management, and customer service
# * **Transportation**: Self-driving cars, route optimization, and logistics management
# * **Education**: AI-based learning platforms, adaptive learning, and student assessment
# * **Customer Service**: Chatbots, virtual assistants, and sentiment analysis
#
# **VI. Benefits of AI**
#
# * **Increased Efficiency**: Automation of repetitive tasks and processes
# * **Improved Accuracy**: Reduced errors and enhanced decision-making
# * **Enhanced Customer Experience**: Personalized services and support
# * **New Business Opportunities**: Creation of new industries and job roles
#
# **VII. Challenges and Concerns**
#
# * **Job Displacement**: The potential for AI to replace human workers
# * **Bias and Discrimination**: The risk of AI systems perpetuating existing biases
# * **Security and Privacy**: The vulnerability of AI systems to cyber attacks and data breaches
# * **Ethics and Accountability**: The need for responsible AI development and deployment
#
# **VIII. Future of AI**
#
# * **Trends and Predictions**: The growth of AI adoption, advancements in AI technologies, and emerging applications
# * **Potential Breakthroughs**: The development of more sophisticated AI systems, such as general or strong AI
# * **Call to Action**: The need for individuals, organizations, and governments to work together to ensure the responsible development and deployment of AI
#
# **IX. Conclusion**
#
# * Recap of the rise of AI and its impact on various industries and aspects of our lives
# * Final thoughts: The future of AI holds tremendous promise, but it also requires careful consideration and responsible development to ensure that its benefits are realized and its risks are mitigated.
#
# This outline provides a comprehensive framework for exploring the topic of the rise of AI, covering its history, types, technologies, impact on industries, benefits, challenges, and future prospects.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI: Transforming the World and Our Lives**
#
# Artificial Intelligence (AI) has become an integral part of our daily lives, and its growing importance cannot be overstated. From virtual assistants to self-driving cars, AI is revolutionizing the way we live, work, and interact with each other. The rise of AI is transforming the world, and its impact will be felt across various industries and aspects of our lives. In this blog, we will explore the history of AI, its types, technologies, impact on industries, benefits, challenges, and future prospects.
#
# **A Brief History of AI**
#
# The concept of Artificial Intelligence dates back to the 1950s, when a group of computer scientists and mathematicians, including John McCarthy, Marvin Minsky, and Nathaniel Rochester, proposed the idea of creating machines that could think and learn like humans. The Dartmouth Summer Research Project on Artificial Intelligence, held in 1956, is considered the birthplace of AI as a field of research. The first AI program, Logical Theorist, was developed in 1956 by Allen Newell and Herbert Simon, and it was designed to simulate human problem-solving abilities.
#
# In the 1960s, the first AI laboratory was established, and the field began to gain momentum. The introduction of expert systems in the 1970s marked a significant milestone in the development of AI, as it enabled machines to make decisions based on predefined rules and knowledge. The 1980s saw the rise of machine learning, which allowed AI systems to learn from data and improve their performance over time. Today, AI is an integral part of our daily lives, and its presence is felt in various industries, from healthcare and finance to transportation and education.
#
# **Types of AI**
#
# There are several types of AI, each with its own unique characteristics and capabilities. **Narrow or Weak AI** is designed to perform a specific task, such as image recognition, language translation, or playing chess. This type of AI is the most common and is used in a wide range of applications, from virtual assistants to self-driving cars. **General or Strong AI**, on the other hand, is a hypothetical AI system that possesses human-like intelligence and can perform any intellectual task. While we are still far from achieving general AI, researchers are making significant progress in developing more advanced AI systems.
#
# **Superintelligence** refers to an AI system that significantly surpasses human intelligence, and it is a topic of much debate and speculation. While some experts believe that superintelligence could be a game-changer for humanity, others are concerned about its potential risks and consequences. Examples of AI applications include virtual assistants like Siri and Alexa, self-driving cars, chatbots, and language translation software.
#
# **AI Technologies**
#
# AI is built on several key technologies, including **Machine Learning (ML)**, **Deep Learning (DL)**, **Natural Language Processing (NLP)**, and **Computer Vision**. Machine Learning is a subset of AI that enables systems to learn from data, and it is used in a wide range of applications, from image recognition to speech recognition. Deep Learning is a type of ML that uses neural networks to analyze data, and it has been instrumental in achieving state-of-the-art results in various AI tasks.
#
# Natural Language Processing is a field of AI that deals with human-computer interaction, and it is used in applications such as language translation, sentiment analysis, and text summarization. Computer Vision is a field of AI that enables computers to interpret and understand visual data, and it is used in applications such as image recognition, object detection, and facial recognition.
#
# **Impact of AI on Industries**
#
# AI is transforming various industries, from healthcare and finance to transportation and education. In **healthcare**, AI is being used to develop personalized medicine, improve patient care, and enhance diagnosis. AI-powered systems can analyze medical images, identify patterns, and make predictions, enabling doctors to make more accurate diagnoses and develop more effective treatment plans.
#
# In **finance**, AI is being used to power trading platforms, manage risk, and provide customer service. AI-powered systems can analyze large amounts of data, identify trends, and make predictions, enabling financial institutions to make more informed decisions. In **transportation**, AI is being used to develop self-driving cars, optimize routes, and manage logistics. Self-driving cars can reduce accidents, improve traffic flow, and enhance the overall driving experience.
#
# In **education**, AI is being used to develop personalized learning platforms, adaptive learning systems, and student assessment tools. AI-powered systems can analyze student data, identify knowledge gaps, and provide personalized recommendations, enabling students to learn more effectively. In **customer service**, AI is being used to power chatbots, virtual assistants, and sentiment analysis tools. AI-powered systems can analyze customer data, identify patterns, and provide personalized support, enabling companies to improve customer satisfaction and loyalty.
#
# **Benefits of AI**
#
# The benefits of AI are numerous and significant. **Increased Efficiency** is one of the most significant advantages of AI, as it can automate repetitive tasks and processes, freeing up human resources for more strategic and creative work. **Improved Accuracy** is another benefit of AI, as it can reduce errors and enhance decision-making by analyzing large amounts of data and identifying patterns.
#
# **Enhanced Customer Experience** is also a significant benefit of AI, as it can provide personalized services and support, enabling companies to improve customer satisfaction and loyalty. **New Business Opportunities** are being created by AI, as it enables companies to develop new products and services, enter new markets, and create new revenue streams.
#
# **Challenges and Concerns**
#
# While AI offers many benefits, it also raises several challenges and concerns. **Job Displacement** is one of the most significant concerns, as AI has the potential to replace human workers, particularly in industries where tasks are repetitive or can be automated. **Bias and Discrimination** is another concern, as AI systems can perpetuate existing biases and discriminate against certain groups of people.
#
# **Security and Privacy** is also a significant concern, as AI systems can be vulnerable to cyber attacks and data breaches, compromising sensitive information and putting individuals and organizations at risk. **Ethics and Accountability** are essential considerations in AI development and deployment, as companies and organizations must ensure that AI systems are developed and used responsibly, with transparency, accountability, and fairness.
#
# **Future of AI**
#
# The future of AI is exciting and uncertain, with many trends and predictions emerging. **Growth of AI Adoption** is expected to continue, with more companies and organizations adopting AI technologies to improve efficiency, accuracy, and customer experience. **Advancements in AI Technologies** are expected to drive innovation, with significant progress being made in areas such as machine learning, deep learning, and natural language processing.
#
# **Potential Breakthroughs** in AI could lead to the development of more sophisticated AI systems, such as general or strong AI, which could have a profound impact on humanity. However, it is essential to ensure that AI is developed and deployed responsibly, with careful consideration of its potential risks and consequences.
#
# **Conclusion**
#
# The rise of AI is transforming the world, and its impact will be felt across various industries and aspects of our lives. While AI offers many benefits, it also raises several challenges and concerns. As we move forward, it is essential to ensure that AI is developed and deployed responsibly, with transparency, accountability, and fairness. The future of AI holds tremendous promise, but it also requires careful consideration and responsible development to ensure that its benefits are realized and its risks are mitigated. By working together, we can harness the power of AI to create a better future for all.
